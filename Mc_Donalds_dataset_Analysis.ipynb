# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('/root/Desktop/menu.xlsx')

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                           25.0
# 1                           12            3.0                           15.0
# 2                           35            8.0                           42.0
# 3                           43           10.0                           52.0
# 4                           35            8.0                           42.0
# ..                         ...            ...                            ...
# 255                         26            9.0                           44.0
# 256                         35           12.0                           58.0
# 257                         17            6.0                            NaN
# 258                         50           15.0                           76.0
# 259                         25            8.0                           38.0
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...           31.0                           10.0
# 1          0.0  ...           30.0                           10.0
# 2          0.0  ...           29.0                           10.0
# 3          0.0  ...           30.0                           10.0
# 4          0.0  ...           30.0                           10.0
# ..         ...  ...            ...                            ...
# 255        0.5  ...           80.0                           27.0
# 256        1.0  ...          106.0                           35.0
# 257        0.0  ...           53.0                            NaN
# 258        1.0  ...          114.0                            NaN
# 259        0.0  ...           57.0                           19.0
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                           17.0     3.0     17.0
# 1                4                           17.0     3.0     18.0
# 2                4                           17.0     2.0     14.0
# 3                4                           17.0     2.0     21.0
# 4                4                           17.0     2.0     21.0
# ..             ...                            ...     ...      ...
# 255              1                            4.0    64.0     12.0
# 256              1                            5.0    85.0     15.0
# 257              1                            2.0    43.0      8.0
# 258              2                            9.0   103.0     21.0
# 259              1                            5.0    51.0     10.0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                         10.0                        0.0
# 1                          6.0                        0.0
# 2                          8.0                        0.0
# 3                         15.0                        0.0
# 4                          6.0                        0.0
# ..                         ...                        ...
# 255                       15.0                        0.0
# 256                       20.0                        0.0
# 257                       10.0                        0.0
# 258                       20.0                        0.0
# 259                       10.0                        0.0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                       25.0                  15.0
# 1                       25.0                   8.0
# 2                       25.0                  10.0
# 3                       30.0                  15.0
# 4                       25.0                  10.0
# ..                       ...                   ...
# 255                     40.0                   8.0
# 256                     50.0                  10.0
# 257                     25.0                   6.0
# 258                     60.0                   6.0
# 259                     30.0                   4.0
#
# [260 rows x 24 columns]

# %%
df.isnull()
# Out:
#      Category   Item  Serving Size  Calories  Calories from Fat  Total Fat  \
# 0       False  False         False     False              False      False
# 1       False  False         False     False              False      False
# 2       False  False         False     False              False      False
# 3       False  False         False     False              False      False
# 4       False  False         False     False              False      False
# ..        ...    ...           ...       ...                ...        ...
# 255     False  False         False     False              False      False
# 256     False  False         False     False              False      False
# 257     False  False         False     False              False      False
# 258     False  False         False     False              False      False
# 259     False  False         False     False              False      False
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                        False          False                          False
# 1                        False          False                          False
# 2                        False          False                          False
# 3                        False          False                          False
# 4                        False          False                          False
# ..                         ...            ...                            ...
# 255                      False          False                          False
# 256                      False          False                          False
# 257                      False          False                           True
# 258                      False          False                          False
# 259                      False          False                          False
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0        False  ...          False                          False
# 1        False  ...          False                          False
# 2        False  ...          False                          False
# 3        False  ...          False                          False
# 4        False  ...          False                          False
# ..         ...  ...            ...                            ...
# 255      False  ...          False                          False
# 256      False  ...          False                          False
# 257      False  ...          False                           True
# 258      False  ...          False                           True
# 259      False  ...          False                          False
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0            False                          False   False    False
# 1            False                          False   False    False
# 2            False                          False   False    False
# 3            False                          False   False    False
# 4            False                          False   False    False
# ..             ...                            ...     ...      ...
# 255          False                          False   False    False
# 256          False                          False   False    False
# 257          False                          False   False    False
# 258          False                          False   False    False
# 259          False                          False   False    False
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
# ..                         ...                        ...
# 255                      False                      False
# 256                      False                      False
# 257                      False                      False
# 258                      False                      False
# 259                      False                      False
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                      False                 False
# 1                      False                 False
# 2                      False                 False
# 3                      False                 False
# 4                      False                 False
# ..                       ...                   ...
# 255                    False                 False
# 256                    False                 False
# 257                    False                 False
# 258                    False                 False
# 259                    False                 False
#
# [260 rows x 24 columns]

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  259.000000                 260.000000
# mean    368.269231         127.096154   14.034749                  21.815385
# std     240.269886         127.875914   14.076162                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.250000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.000000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     258.000000                     256.000000  257.000000   254.000000
# mean        5.961240                      29.675781    0.204280    54.980315
# std         5.313192                      26.369775    0.430866    87.239729
# min         0.000000                       0.000000    0.000000     0.000000
# 25%         1.000000                       4.750000    0.000000     5.000000
# 50%         5.000000                      24.000000    0.000000    35.000000
# 75%         9.750000                      48.000000    0.000000    65.000000
# max        20.000000                     102.000000    2.500000   575.000000
#
#        Cholesterol (% Daily Value)       Sodium  ...  Carbohydrates  \
# count                   259.000000   258.000000  ...     259.000000
# mean                     18.370656   497.344961  ...      47.297297
# std                      29.145879   578.979904  ...      28.295924
# min                       0.000000     0.000000  ...       0.000000
# 25%                       2.000000   102.500000  ...      30.000000
# 50%                      11.000000   190.000000  ...      44.000000
# 75%                      21.000000   875.000000  ...      60.000000
# max                     192.000000  3600.000000  ...     141.000000
#
#        Carbohydrates (% Daily Value)  Dietary Fiber  \
# count                     256.000000     260.000000
# mean                       15.730469       1.630769
# std                         9.375480       1.567717
# min                         0.000000       0.000000
# 25%                        10.000000       0.000000
# 50%                        15.000000       1.000000
# 75%                        20.000000       3.000000
# max                        47.000000       7.000000
#
#        Dietary Fiber (% Daily Value)      Sugars     Protein  \
# count                     259.000000  259.000000  259.000000
# mean                        6.544402   29.162162   13.343629
# std                         6.315429   28.424467   11.447964
# min                         0.000000    0.000000    0.000000
# 25%                         0.000000    5.500000    4.000000
# 50%                         5.000000   17.000000   12.000000
# 75%                        10.000000   48.000000   19.000000
# max                        28.000000  128.000000   87.000000
#
#        Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count                 258.000000                 259.000000
# mean                   13.406977                   8.559846
# std                    24.428747                  26.393403
# min                     0.000000                   0.000000
# 25%                     2.000000                   0.000000
# 50%                     8.000000                   0.000000
# 75%                    15.000000                   4.000000
# max                   170.000000                 240.000000
#
#        Calcium (% Daily Value)  Iron (% Daily Value)
# count               257.000000            258.000000
# mean                 20.809339              7.786822
# std                  17.010987              8.736362
# min                   0.000000              0.000000
# 25%                   6.000000              0.000000
# 50%                  20.000000              4.000000
# 75%                  30.000000             15.000000
# max                  70.000000             40.000000
#
# [8 rows x 21 columns]

# %%
# Cleaning the data

# %%
df=df[["Category","Item","Calories","Total Fat (% Daily Value)","Saturated Fat (% Daily Value)","Cholesterol (% Daily Value)","Sodium (% Daily Value)","Carbohydrates (% Daily Value)","Dietary Fiber (% Daily Value)","Vitamin A (% Daily Value)","Vitamin C (% Daily Value)","Calcium (% Daily Value)","Iron (% Daily Value)","Protein","Sugars","Trans Fat"]]

# %%
df.rename(columns = {"Total Fat (% Daily Value)":"Total Fat","Saturated Fat (% Daily Value)":"Saturated Fat","Cholesterol (% Daily Value)":"Cholesterol","Sodium (% Daily Value)":"Sodium","Carbohydrates (% Daily Value)":"Carbohydrates","Dietary Fiber (% Daily Value)":"Dietary Fiber","Vitamin A (% Daily Value)":"Vitamin A","Vitamin C (% Daily Value)":"Vitamin C","Calcium (% Daily Value)":"Calcium","Iron (% Daily Value)":"Iron"},inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
sns.heatmap(df.isnull())

# %%
df = df.sort_values(by="Category")

# %%
df
# Out:
#            Category                                       Item  Calories  \
# 42      Beef & Pork                                    Big Mac       530
# 56      Beef & Pork                                      McRib       500
# 55      Beef & Pork                           Jalape̱o Double       430
# 54      Beef & Pork                               Daily Double       430
# 52      Beef & Pork                                   McDouble       380
# ..              ...                                        ...       ...
# 92   Snacks & Sides  Honey Mustard Snack Wrap (Crispy Chicken)       330
# 91   Snacks & Sides  Chipotle BBQ Snack Wrap (Grilled Chicken)       260
# 90   Snacks & Sides   Chipotle BBQ Snack Wrap (Crispy Chicken)       340
# 96   Snacks & Sides                         Small French Fries       230
# 100  Snacks & Sides                                 Side Salad        20
#
#      Total Fat  Saturated Fat  Cholesterol  Sodium  Carbohydrates  \
# 42          42           48.0         28.0    40.0           16.0
# 56          40           48.0         23.0    41.0           15.0
# 55          36           44.0         27.0    43.0           12.0
# 54          35           44.0         27.0    32.0           11.0
# 52          26           40.0         25.0    35.0           11.0
# ..         ...            ...          ...     ...            ...
# 92          23           22.0         11.0    30.0           11.0
# 91          13           18.0         14.0    29.0           10.0
# 90          23           22.0         11.0    33.0           12.0
# 96          17            8.0          0.0     5.0           10.0
# 100          0            0.0          0.0     0.0            1.0
#
#      Dietary Fiber  Vitamin A  Vitamin C  Calcium  Iron  Protein  Sugars  \
# 42            13.0        6.0        2.0     25.0  25.0     24.0     9.0
# 56            10.0        2.0        2.0     15.0  20.0     22.0    11.0
# 55             7.0        6.0        8.0     20.0  20.0     22.0     6.0
# 54             8.0        8.0        8.0     20.0  20.0     22.0     7.0
# 52             7.0        6.0        2.0     20.0  20.0     22.0     7.0
# ..             ...        ...        ...      ...   ...      ...     ...
# 92             5.0        2.0        0.0     10.0  10.0     14.0     3.0
# 91             6.0        4.0        2.0     10.0  10.0     16.0     7.0
# 90             6.0        4.0        0.0     10.0  10.0     14.0     8.0
# 96            10.0        0.0       30.0      0.0   4.0      2.0     0.0
# 100            6.0       45.0       25.0      2.0   4.0      1.0     2.0
#
#      Trans Fat
# 42         1.0
# 56         0.0
# 55         1.0
# 54         1.0
# 52         1.0
# ..         ...
# 92         0.0
# 91         0.0
# 90         0.0
# 96         0.0
# 100        0.0
#
# [260 rows x 16 columns]

# %%
df.pivot_table('Protein', 'Category')
# Out:
#                       Protein
# Category
# Beef & Pork         27.333333
# Beverages            1.333333
# Breakfast           19.857143
# Chicken & Fish      29.111111
# Coffee & Tea         8.863158
# Desserts             4.000000
# Salads              19.833333
# Smoothies & Shakes  10.814815
# Snacks & Sides       8.384615

# %%
df.pivot_table('Vitamin A', 'Category').plot(kind='bar', stacked=True, color = 'b')

# %%
sns.set(style="whitegrid", color_codes=True)
ax= sns.swarmplot(x="Category", y="Vitamin A", data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# /usr/lib/python3/dist-packages/seaborn/categorical.py:1311: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# /usr/lib/python3/dist-packages/seaborn/categorical.py:1315: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.set(style="whitegrid", color_codes=True)
ax= sns.swarmplot(x="Category", y="Vitamin A", data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Beef & Pork'),
#  Text(0, 0, 'Beverages'),
#  Text(0, 0, 'Breakfast'),
#  Text(0, 0, 'Chicken & Fish'),
#  Text(0, 0, 'Coffee & Tea'),
#  Text(0, 0, 'Desserts'),
#  Text(0, 0, 'Salads'),
#  Text(0, 0, 'Smoothies & Shakes'),
#  Text(0, 0, 'Snacks & Sides')]

# %%
df.pivot_table('Vitamin C', 'Category').plot(kind='bar', stacked=True, color = 'r')

# %%
sns.set(style="whitegrid", color_codes=True)
ax1= sns.swarmplot(x="Category", y="Vitamin C", data=df)
#ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)

# %%
sns.set(style="whitegrid", color_codes=True)
ax1= sns.swarmplot(x="Category", y="Vitamin C", data=df)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Beef & Pork'),
#  Text(0, 0, 'Beverages'),
#  Text(0, 0, 'Breakfast'),
#  Text(0, 0, 'Chicken & Fish'),
#  Text(0, 0, 'Coffee & Tea'),
#  Text(0, 0, 'Desserts'),
#  Text(0, 0, 'Salads'),
#  Text(0, 0, 'Smoothies & Shakes'),
#  Text(0, 0, 'Snacks & Sides')]

# %%
df.Category.value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df.Category.value_counts().plot.pie()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix , square = True) #annot = True will show the relation between the values

# %%
# This is a little complicated 
corr_matrix = df.corr()
sns.heatmap(corr_matrix , square = True , annot = True , fmt = '0.1')

# %%
# either Crispy or Fried Which is healthy

# %%
df['isGrilled']=df.Item.str.contains("Grilled")
df['isCrispy']= df.Item.str.contains("Crispy")

# %%
df[df["isCrispy"] == True]
# Out:
#           Category                                               Item  \
# 59  Chicken & Fish               Premium Crispy Chicken Club Sandwich
# 57  Chicken & Fish            Premium Crispy Chicken Classic Sandwich
# 61  Chicken & Fish          Premium Crispy Chicken Ranch BLT Sandwich
# 70  Chicken & Fish    Premium McWrap Chicken & Bacon (Crispy Chicken)
# 63  Chicken & Fish            Bacon Clubhouse Crispy Chicken Sandwich
# 72  Chicken & Fish    Premium McWrap Chicken & Ranch (Crispy Chicken)
# 74  Chicken & Fish  Premium McWrap Southwest Chicken (Crispy Chicken)
# 76  Chicken & Fish  Premium McWrap Chicken Sweet Chili (Crispy Chi...
# 65  Chicken & Fish             Southern Style Crispy Chicken Sandwich
# 85          Salads      Premium Bacon Ranch Salad with Crispy Chicken
# 88          Salads        Premium Southwest Salad with Crispy Chicken
# 94  Snacks & Sides                  Ranch Snack Wrap (Crispy Chicken)
# 92  Snacks & Sides          Honey Mustard Snack Wrap (Crispy Chicken)
# 90  Snacks & Sides           Chipotle BBQ Snack Wrap (Crispy Chicken)
#
#     Calories  Total Fat  Saturated Fat  Cholesterol  Sodium  Carbohydrates  \
# 59       670         51           44.0         29.0    59.0           19.0
# 57       510         33           18.0         16.0    41.0           18.0
# 61       610         43           31.0         24.0    58.0           19.0
# 70       630         49           45.0         26.0    64.0           19.0
# 63       750         59           51.0         31.0    72.0           22.0
# 72       610         47           40.0         21.0    56.0           19.0
# 74       670         51           40.0         21.0    62.0           23.0
# 76       540         35           23.0         16.0    52.0           20.0
# 65       430         29           15.0         14.0    38.0           14.0
# 85       380         33           29.0         23.0    36.0            7.0
# 88       450         33           22.0         17.0    35.0           14.0
# 94       360         30           27.0         13.0    34.0           11.0
# 92       330         23           22.0         11.0    30.0           11.0
# 90       340         23           22.0         11.0    33.0           12.0
#
#     Dietary Fiber  Vitamin A  Vitamin C  Calcium  Iron  Protein  Sugars  \
# 59           14.0        8.0       20.0     30.0  20.0     36.0    11.0
# 57           13.0        4.0        6.0     15.0  20.0     24.0    10.0
# 61           13.0        4.0       20.0     15.0  20.0     32.0    11.0
# 70           13.0       60.0       20.0     20.0  20.0     32.0     7.0
# 63           15.0        8.0       25.0     30.0  15.0     36.0    16.0
# 72           14.0       60.0       15.0     20.0  20.0     27.0     8.0
# 74           19.0       60.0       15.0     20.0  20.0     27.0    12.0
# 76           13.0       60.0       15.0      8.0  20.0     23.0    14.0
# 65            7.0        4.0        2.0     15.0  15.0     21.0     7.0
# 85           10.0      100.0       25.0     15.0   8.0     25.0     5.0
# 88           28.0      170.0       30.0     15.0  15.0     23.0    12.0
# 94            5.0        2.0        0.0     10.0  10.0     15.0     3.0
# 92            5.0        2.0        0.0     10.0  10.0     14.0     3.0
# 90            6.0        4.0        0.0     10.0  10.0     14.0     8.0
#
#     Trans Fat  isGrilled  isCrispy
# 59        0.0      False      True
# 57        0.0      False      True
# 61        0.0      False      True
# 70        0.5      False      True
# 63        0.5      False      True
# 72        0.5      False      True
# 74        0.5      False      True
# 76        0.0      False      True
# 65        0.0      False      True
# 85        0.0      False      True
# 88        0.0      False      True
# 94        0.0      False      True
# 92        0.0      False      True
# 90        0.0      False      True

# %%
grilled_df = df[df['isGrilled'] == True]
crispy_df = df[df['isCrispy'] == True]
grilled_df=grilled_df[['Item','Total Fat','Calories']]
crispy_df=crispy_df[['Item','Total Fat','Calories']]

# %%
df1=grilled_df.reset_index(drop=True).merge(crispy_df.reset_index(drop=True),left_index=True,right_index=True)

# %%
# was expecting this error
# solved in the next line code
df1.columns=['Items-Grilled','TotalFat-Grilled','Calories-Grilled','TotalFat-Crispy','Calories-Crispy']
# Out:
# -----------------------------------------------------------------
# ValueError                      Traceback (most recent call last)
# <ipython-input-26-755182aa41f9> in <module>
# ----> 1 df1.columns=['Items-Grilled','TotalFat-Grilled','Calories-Grilled','TotalFat-Crispy','Calories-Crispy']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     179
#     180         if new_len != old_len:
# --> 181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
#     183                 "values have {new} elements".format(old=old_len, new=new_len)
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 5 elements

# %%
df1.columns=['Items-Grilled','TotalFat-Grilled','Calories-Grilled','Items-Crispy','TotalFat-Crispy','Calories-Crispy']
df1=df1.drop('Items-Crispy',axis=1)

# %%
df1.head()
# Out:
#                                        Items-Grilled  TotalFat-Grilled  \
# 0              Premium Grilled Chicken Club Sandwich                31
# 1   Premium McWrap Chicken & Bacon (Grilled Chicken)                28
# 2           Premium Grilled Chicken Classic Sandwich                13
# 3  Premium McWrap Chicken Sweet Chili (Grilled Ch...                15
# 4   Premium McWrap Chicken & Ranch (Grilled Chicken)                27
#
#    Calories-Grilled  TotalFat-Crispy  Calories-Crispy
# 0               510               51              670
# 1               480               33              510
# 2               350               43              610
# 3               380               49              630
# 4               450               59              750

# %%
df1['Item']=df1['Items-Grilled'].str.replace("Grilled","")

# %%
df1=df1.drop('Items-Grilled',axis=1)

# %%
df1.head()
# Out:
#    TotalFat-Grilled  Calories-Grilled  TotalFat-Crispy  Calories-Crispy  \
# 0                31               510               51              670
# 1                28               480               33              510
# 2                13               350               43              610
# 3                15               380               49              630
# 4                27               450               59              750
#
#                                             Item
# 0                 Premium  Chicken Club Sandwich
# 1      Premium McWrap Chicken & Bacon ( Chicken)
# 2              Premium  Chicken Classic Sandwich
# 3  Premium McWrap Chicken Sweet Chili ( Chicken)
# 4      Premium McWrap Chicken & Ranch ( Chicken)

# %%
df1.drop(columns="Item",inplace=True)

# %%
df1["TotalFat-Crispy"].replace({43:33},inplace=True)
df1.iloc[[2,0]]
# Out:
#    TotalFat-Grilled  Calories-Grilled  TotalFat-Crispy  Calories-Crispy
# 2                13               350               33              610
# 0                31               510               51              670

# %%
df1[["TotalFat-Grilled","TotalFat-Crispy"]].plot(kind="barh")

# %%
df1[["Calories-Grilled","Calories-Crispy"]].plot(kind="barh")
