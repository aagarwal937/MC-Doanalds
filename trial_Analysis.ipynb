# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/root/Desktop/menu.xlsx')

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
# Category                         260 non-null object
# Item                             260 non-null object
# Serving Size                     260 non-null object
# Calories                         260 non-null int64
# Calories from Fat                260 non-null int64
# Total Fat                        259 non-null float64
# Total Fat (% Daily Value)        260 non-null int64
# Saturated Fat                    258 non-null float64
# Saturated Fat (% Daily Value)    256 non-null float64
# Trans Fat                        257 non-null float64
# Cholesterol                      254 non-null float64
# Cholesterol (% Daily Value)      259 non-null float64
# Sodium                           258 non-null float64
# Sodium (% Daily Value)           257 non-null float64
# Carbohydrates                    259 non-null float64
# Carbohydrates (% Daily Value)    256 non-null float64
# ...

# %%
df.iloc[57:61]
# Out:
#           Category                                      Item    Serving Size  \
# 57  Chicken & Fish   Premium Crispy Chicken Classic Sandwich  7.5 oz (213 g)
# 58  Chicken & Fish  Premium Grilled Chicken Classic Sandwich    7 oz (200 g)
# 59  Chicken & Fish      Premium Crispy Chicken Club Sandwich  8.8 oz (249 g)
# 60  Chicken & Fish     Premium Grilled Chicken Club Sandwich  8.3 oz (235 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 57       510                200       22.0                         33
# 58       350                 80        9.0                         13
# 59       670                300       33.0                         51
# 60       510                180       20.0                         31
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 57            3.5                           18.0        0.0  ...
# 58            2.0                            9.0        0.0  ...
# ...

# %%
sns.heatmap(df.isnull())

# %%
df = df.interpolate(method = 'linear' , limit_direction = 'forward')

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().plot.pie()

# %%
df.groupby('Category').mean()['Protein']
# Out:
# Category
# Beef & Pork           27.333333
# Beverages              1.333333
# Breakfast             19.857143
# Chicken & Fish        29.111111
# Coffee & Tea           8.863158
# Desserts               4.000000
# Salads                19.833333
# Smoothies & Shakes    11.017857
# Snacks & Sides         8.384615
# Name: Protein, dtype: float64

# %%
df.groupby('Category').mean()['Protein'].plot(kind = 'bar' , stacked = 'True' ,color = 'b')

# %%
df.groupby('Category').mean()['Carbohydrates'].plot(kind = 'bar' , stacked = 'True' ,color = 'y')

# %%
sns.set(style = 'whitegrid' , color_codes = True)
ax1 = sns.swarmplot(x = 'Category' , y = 'Vitamin C (% Daily Value)' , data = df)

# %%
sns.set(style = 'whitegrid' , color_codes = True)
ax1 = sns.swarmplot(x = 'Category' , y = 'Vitamin C (% Daily Value)' , data = df)
ax1.set_xticklabels(ax1.get_xticklabels() , rotation = 90)
# Out:
# [Text(0, 0, 'Breakfast'),
#  Text(0, 0, 'Beef & Pork'),
#  Text(0, 0, 'Chicken & Fish'),
#  Text(0, 0, 'Salads'),
#  Text(0, 0, 'Snacks & Sides'),
#  Text(0, 0, 'Desserts'),
#  Text(0, 0, 'Beverages'),
#  Text(0, 0, 'Coffee & Tea'),
#  Text(0, 0, 'Smoothies & Shakes')]

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix , square = True) #annot = True will show the relation between the values

# %%
corr_matrix = df.corr()
ax = sns.heatmap(corr_matrix , square = True , annot = True , fmt = '0.1')

# %%
# krispy or fried which is healthy

# %%
df[['TotalFat-Grilled' , 'Totalfat-Crispy']].plot(kind = 'barh')
# Out:
# -----------------------------------------------------------------
# KeyError                        Traceback (most recent call last)
# <ipython-input-44-d220464ef0b7> in <module>
# ----> 1 df[['TotalFat-Grilled' , 'Totalfat-Crispy']].plot(kind = 'barh')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
# ...
